# %% [markdown]
# ## Descomposición de Valores singulares

# %% [markdown]
# **Definición**. Sea una $M$ una matriz de $mxn$ con rank r (número de columnas o filas linealmente independientes). Se pueden encontrar matrices $U,\Sigma, V$ tales que

# %% [markdown]
# $$M = U \Sigma V^{T}$$

# %% [markdown]
# Donde:
#
# $U$ es una matriz _ortonormal_ de mxm
#
# $V^{T}$ es una matriz _ortonormal_ de nxn
#
# $\Sigma$ es una matriz diagonal de mxn.

# %% [markdown]
# A la descomposición anterior se le conoce como _full svd_ (por sus siglas en inglés singular Value Decomposition)

# %% [markdown]
# ![full_svd.png](attachment:full_svd.png)

# %% [markdown]
# Observaciones.
# * Las columnas vector de $U$ son los vectores singulares izquierdos de $M$
# * Las columnas vector de $V^{T}$ son los vectores singulares derechos de $M$
# * Los elementos de la diagonal de $\Sigma$ denotados por $\sigma_{i}$ se les conoce como _valores singulares_ de $M$ y por convención  $\sigma_{1}\geq\sigma_{2}\geq\cdots\geq\sigma_{r}$

# %% [markdown]
# Notar que la matriz $\Sigma$ es del mismo tamaño que $M$. Entonces si $M$ es rectangular va a existir una submatriz cuadrada y diagonal en $\Sigma$ con los valores singulares y una submatriz de ceros para completar la matriz $\Sigma$. Así entonces podemos regresentar la descomposición SVD en su forma _thin_ ocupando una matiz $\Sigma$ reducida.

# %% [markdown]
# ![casos_svd.png](attachment:casos_svd.png)

# %% [markdown]
# ![factorizacion_svd.png](attachment:factorizacion_svd.png)

# %% [markdown]
# La interpretación geometrica de la _SVD_ es la siguiente:

# %% [markdown]
# ![diagrama_svd.png](attachment:diagrama_svd.png)

# %% [markdown]
# **Ejemplo**
#
# * caso:  m > n

# %%
# Importar librerías
import numpy as np
import pandas as pd 
from sklearn import datasets


import matplotlib.pyplot as plt
from PIL import Image

# %%
# Caso 1
# Leer el conjunto de datos Iris
iris = datasets.load_iris()
X = iris.data[:, :4]

# %%
X.shape
# Out:
# (150, 4)

# %% [markdown]
# **Importante**. Conocer tus datos

# %%
#iris

# %%
# Calcular Full SVD
U, S, Vt = np.linalg.svd(X)

# %%
print(U.shape)
print(S.shape)
print(Vt.shape)
# Out:
# (150, 150)
# (4,)
# (4, 4)

# %%
# Calcular SVD
U, S, Vt = np.linalg.svd(X, full_matrices=False)

# %%
print(U.shape)
print(S.shape)
print(Vt.shape)
# Out:
# (150, 4)
# (4,)
# (4, 4)

# %%
print(U)
# Out:
# [[-6.16168450e-02  1.29611444e-01  2.13859674e-03  1.63819140e-03]
#  [-5.80709402e-02  1.11019776e-01  7.06723871e-02  5.17569646e-02]
#  [-5.67630474e-02  1.17966465e-01  4.34254909e-03  9.55702427e-03]
#  [-5.66534426e-02  1.05308145e-01  5.92467197e-03 -4.16438911e-02]
#  [-6.12302023e-02  1.31089790e-01 -3.18810953e-02 -3.22148124e-02]
#  [-6.75031684e-02  1.30884835e-01 -6.85371918e-02 -1.13642477e-02]
#  [-1.01466857e-01 -7.26079359e-02 -9.54496061e-02  3.14227537e-02]
#  [-1.00360953e-01 -6.70195388e-02 -1.57083258e-01  1.28363417e-01]
#  [-9.61496966e-02 -5.24346281e-02 -5.89711154e-02  2.26608556e-01]
#  [-8.92692075e-02 -5.85064019e-02  4.60293941e-02  1.34134615e-01]
#  [-9.40593040e-02 -4.98296974e-02 -4.14400144e-02  7.28944729e-02]
#  [-9.48896096e-02 -5.61012256e-02 -2.12978214e-01  2.31635137e-02]
#  [-8.84783560e-02 -5.15697045e-02 -9.57528475e-02 -8.35063456e-02]]

# %%
print(np.diag(S))
# Out:
# [[95.95991387  0.          0.          0.        ]
#  [ 0.         17.76103366  0.          0.        ]
#  [ 0.          0.          3.46093093  0.        ]
#  [ 0.          0.          0.          1.88482631]]

# %%
print(Vt)
# Out:
# [[-0.75110816 -0.38008617 -0.51300886 -0.16790754]
#  [ 0.2841749   0.5467445  -0.70866455 -0.34367081]
#  [ 0.50215472 -0.67524332 -0.05916621 -0.53701625]
#  [ 0.32081425 -0.31725607 -0.48074507  0.75187165]]

# %%
# Corroborar la descomposición
#help(np.round)
sum(np.round((X - U@(np.diag(S))@Vt),4))
# Out:
# array([0., 0., 0., 0.])

# %% [markdown]
# Corroborar que los vectores columna de $U$ son ortogonales, es decir, se debe cumplir que $ U^{T}U = I_{n}$

# %% [markdown]
# Notar que $ UU^{T} \neq I_{m}$ pues estaríamos diciendo que todas las filas de $U$ son ortogonales entre si.

# %%
U.T@U
# Out:
# array([[ 1.00000000e+00, -3.74529031e-17, -4.54798832e-18,
#         -7.47866140e-18],
#        [-3.74529031e-17,  1.00000000e+00,  2.39939118e-16,
#          9.45501965e-17],
#        [-4.54798832e-18,  2.39939118e-16,  1.00000000e+00,
#         -4.56450630e-17],
#        [-7.47866140e-18,  9.45501965e-17, -4.56450630e-17,
#          1.00000000e+00]])

# %% [markdown]
# ### Aplicaciones

# %% [markdown]
# **1. Reducción de Dimensionalidad** (Reconstrucción de imagenes)

# %%
# Importar imagen
imagen = Image.open('/home/leonardo/Documentos/Acatlan/Repositorios/datos_masivos_II_2022/imagenes/escudo_fes_acatlan.jpg')
imagen_gris = imagen.convert('LA')   ## Convertir a escala de grises

# %%
## Convertir la imagen a una matriz

imagen_mat = np.array(list(imagen_gris.getdata(band=0)), float)
imagen_mat.shape = (imagen_gris.size[1], imagen_gris.size[0])
imagen_mat = np.matrix(imagen_mat)

plt.imshow(imagen_mat, cmap='gray')

# %%
# Dimensiones de la imagen
imagen_mat.shape
# Out:
# (1491, 1280)

# %% [markdown]
# Aproximar la imagen

# %%
# SDV 
U, Sigma, Vt = np.linalg.svd(imagen_mat, full_matrices=False)

# %% [markdown]
# Una vez que tenemos la descomposición SVD de una matriz $M$ con rank = r, podemos extraer la aproximación que nos sea útil: una aproximación $M_{k}$ con rank = r (con k < r) se escribe como $M_{k}=U_{k} \Sigma_{k} V^{T}_{k}$  donde $U_{k}$ contiene las primeras k columnas de U, $V_{k}$ las primeras k columnas de V, y $\Sigma_{k}$ es la submatriz cuadrada k×k de los primeros k renglones y columnas de $\Sigma$

# %%
j = 100
matriz_equivalente = np.matrix(U[:, :j]) * np.diag(Sigma[:j]) * np.matrix(Vt[:j, :])
plt.imshow(matriz_equivalente, cmap='gray')

# %%
#Calidad de la aproximación 
1 - (np.linalg.norm(imagen_mat - matriz_equivalente)**2)/(np.linalg.norm(imagen_mat)**2)
# Out:
# 0.9867184279169541

# %% [markdown]
# **2. Solución de Sistemas de ecuaciones** (Pseudo-Inversa)

# %% [markdown]
# La Inversa de una Matriz A se puede calcular a partir de su descomposición SVD por medio de:

# %% [markdown]
# $$A^{-1}=V \Sigma^{-1} U^{T}$$

# %%
A = np.array([[3,4],[1,5]])
A
# Out:
# array([[3, 4],
#        [1, 5]])

# %%
A_1= np.linalg.inv(A)
A_1
# Out:
# array([[ 0.45454545, -0.36363636],
#        [-0.09090909,  0.27272727]])

# %%
def pseudoinversa(M):
    U, S, Vt = np.linalg.svd(M, full_matrices = True)
    peudoinversa =  Vt.T@(np.diag(1/S))@U.T
    return peudoinversa

# %%
B = pseudoinversa(A)
B
# Out:
# array([[ 0.45454545, -0.36363636],
#        [-0.09090909,  0.27272727]])

# %%
np.round(A@A_1,8)
# Out:
# array([[1., 0.],
#        [0., 1.]])

# %%
np.round(A@B,8)
# Out:
# array([[ 1.,  0.],
#        [-0.,  1.]])

# %%
B@A
# Out:
# array([[1., 0.],
#        [0., 1.]])

# %% [markdown]
# ---

# %% [markdown]
# Evaluar la calidad de la aproximacion para cada acumulación de suma de matrices de rango 1

# %%
import pandas as pd

# %%
len(Sigma)
# Out:
# 1280

# %%
num_valores_singulares = []
vector_calidad = []

# %%
for i in range(1,200):
    j = i
    matriz_equivalente = np.matrix(U[:, :j]) * np.diag(Sigma[:j]) * np.matrix(Vt[:j, :])
    calidad = 1 - (np.linalg.norm(imagen_mat - matriz_equivalente)**2)/(np.linalg.norm(imagen_mat)**2)
    
    num_valores_singulares.append(i)
    vector_calidad.append(calidad)

# %%
df = pd.concat([pd.Series(num_valores_singulares), pd.Series(vector_calidad)], axis = 1)
df.columns =["num_valores_singulares","vector_calidad"]
df.head()
# Out:
#    num_valores_singulares  vector_calidad
# 0                       1        0.742972
# 1                       2        0.774881
# 2                       3        0.802754
# 3                       4        0.821370
# 4                       5        0.834444

# %%
df.plot.scatter(x = "num_valores_singulares", y = "vector_calidad")

# %%
j = 25
matriz_equivalente = np.matrix(U[:, :j]) * np.diag(Sigma[:j]) * np.matrix(Vt[:j, :])

# %%
#Calidad de la aproximación 
1 - (np.linalg.norm(imagen_mat - matriz_equivalente)**2)/(np.linalg.norm(imagen_mat)**2)
# Out:
# 0.9300378879037009

# %%
plt.imshow(matriz_equivalente, cmap='gray')

# %%
(Sigma[:j]@Sigma[:j])/(Sigma@Sigma)
# Out:
# 0.9300378879037013
